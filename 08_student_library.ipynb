# %%
class Library:                                                                          # class library
    def __init__ (self, listofBooks):
        self.books = listofBooks
    
    def displayavailablebooks (self):                                                   # this displays list of books
        print ("Books present in  thew library are: ")
        for books in self.books:
            print (' *' + books)
    
    def boorwbook (self, bookname):                                                     # this func is for lending the books
        if book in self.books:
            print(f"You have been issued {bookname}, Please return it before return date.")
            self.books.remove(bookname)
            return True
        else:
            print("Book not available at the moment")
            return False

    def returnbook (self, bookname):                                                       # This func is for taking thje books back from ther reader
        self.books.append(bookname)
        print ("Thanks for returning the book")

    def donatebook (self, bookname):                                                       # This func is for taking donations dfrom any1
        if bookname not in self.books:
            self.books.append(bookname)
            print ("Thanks for donating to the Library")
            return True
        else:
            print ("This book already in Library, would you like to donate another book?")
            return False
        
        
class student:                                                                                 # class student
    
    def requestbook (self):                                                                       # this func is for requesting a book from thr lib.
        self.books = input("Enter the name of the book you want to borrow\n")
        return self.books
    
    def returnBook(self):                                                                       # this func is for returning the book 
        self.book = input("Enter the name of the book you want to return: ")
        return self.book
    
    def donateBook(self):                                                                          # This func is for donating a book 
        self.book = input("Enter the name of the book you want to donate: ")
        return self.book

if __name__ == "__main__":
    Library = Library(["Algorithm" , "Python" , "Anaconda" , "Physics" , "Biology", "Enlisg literature"])
    student = student()
    while (True):
        welcome_message = '''\n ***** Welcone to Library *****
        please choose an option
        1. List all the books
        2. request a book
        3. Donate a book
        4. Return a book
        5. Exit the library'''

        print (welcome_message)
        a = int(input('Enter Your Choice: '))
        if a == 1:
            Library.displayavailablebooks()
        elif a == 2:
            Library.boorwbook(student.requestbook())
        elif a == 3 :
            Library.donatebook(student.donateBook())
        elif a == 4:
            Library.returnbook(student.returnBook())
        elif a == 5:
            print ("Thanks for visiting the Library")
            exit()
        else:
            print ("invalid choice")
# Out:
#  ***** Welcone to Library *****
#         please choose an option
#         1. List all the books
#         2. request a book
#         3. Donate a book
#         4. Return a book
#         5. Exit the library
# Books present in  thew library are:
#  *Algorithm
#  *Python
#  *Anaconda
#  *Physics
#  *Biology
#  *Enlisg literature
#
#  ***** Welcone to Library *****
#         please choose an option
#         1. List all the books
#         2. request a book
#         3. Donate a book
#         4. Return a book
#         5. Exit the library
# Books present in  thew library are:
#  *Algorithm
#  *Python
#  *Anaconda
#  *Physics
#  *Biology
#  *Enlisg literature
#
#  ***** Welcone to Library *****
#         please choose an option
#         1. List all the books
#         2. request a book
#         3. Donate a book
#         4. Return a book
#         5. Exit the library
# ---------------------------------------------------------------------------
# ...
